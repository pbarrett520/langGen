# %%
import pandas as pd

# %%
pd.read_csv('voiceless_consonants.csv')
# Out:
#             Unnamed: 0  bilabial  labiodental  dental  alveolar  postalveolar  \
# 0              plosive         p          NaN     NaN         t           NaN
# 1                nasal       NaN          NaN     NaN       NaN           NaN
# 2                trill       NaN          NaN     NaN       NaN           NaN
# 3                  tap       NaN          NaN     NaN       NaN           NaN
# 4            fricative         ɸ          f.θ       s         ʃ             ʂ
# 5    lateral_fricative       NaN          NaN       ɬ       NaN           NaN
# 6          approximant       NaN          NaN     NaN       NaN           NaN
# 7  lateral_approximant       NaN          NaN     NaN       NaN           NaN
#
#    retroflex  palatal  velar  uvular  pharyngal  glottal
# 0          ʈ        c      k       q        NaN        ʔ
# 1        NaN      NaN    NaN     NaN        NaN      NaN
# 2        NaN      NaN    NaN     NaN        NaN      NaN
# ...

# %%
pd.read_csv('voiced_consonants.csv')
# Out:
#             Unnamed: 0  bilabial  labiodental  dental  alveolar  postalveolar  \
# 0              plosive         b          NaN     NaN         d             ɖ
# 1                nasal         m            ɱ       n       NaN             ɳ
# 2                trill         ʙ          NaN       r       NaN           NaN
# 3                  tap       NaN            ⱱ     NaN         ɾ           NaN
# 4            fricative         β            v       ð         z             ʒ
# 5    lateral_fricative       NaN          NaN     NaN         ɮ           NaN
# 6          approximant       NaN            ʋ     NaN         ɹ           NaN
# 7  lateral_approximant       NaN          NaN     NaN         l           NaN
#
#    retroflex  palatal  velar  uvular  pharyngal  glottal
# 0          ɟ        ɡ      ɢ     NaN        NaN      NaN
# 1        NaN        ɲ      ŋ       ɴ        NaN      NaN
# 2        NaN        ʀ    NaN     NaN        NaN      NaN
# ...

# %%
pd.read_csv('vowels.csv')
# Out:
#    ipa_symbol   Closeness Frontness  Roundness
# 0           i       close     front  unrounded
# 1           y       close     front    rounded
# 2           ɨ       close   central  unrounded
# 3           ʉ       close   central    rounded
# 4           ɯ       close      back  unrounded
# 5           u       close      back    rounded
# 6           ɪ  near-close     front  unrounded
# 7           ʏ  near-close     front    rounded
# 8           ʊ  near-close      back    rounded
# 9           e   close-mid     front  unrounded
# 10          ø   close-mid     front    rounded
# 11          ɘ   close-mid   central  unrounded
# 12          ɵ   close-mid   central    rounded
# 13          ɤ   close-mid      back  unrounded
# 14          o   close-mid      back    rounded
# 15          ə         mid   central  undefined
# 16          ɛ    open-mid     front  unrounded
# 17          œ    open-mid     front    rounded
# 18          ɜ    open-mid   central  unrounded
# ...
